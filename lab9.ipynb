# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    norm_batch = batch - np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(norm_batch)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %%
def relu(batch, stochastic=False):
    if stochastic:
        return np.maximum(0, batch + np.random.normal(scale=np.sqrt(sigmoid(batch)), size=batch.shape))
    else:
        return np.maximum(0, batch)

def relu_derivative(batch):
    return np.where(batch <= 0, 0, 1)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights, limit):
    limits = ones(*weights.shape)
    col_norms = np.linalg.norm(weights, axis=0)
    limits[:, col_norms > limit] = limit / col_norms[col_norms > limit]
    return weights * limits

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):    
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        
        # apply dropout to the MLP input
        # (columns - 1) to ignore biases
        mask_shape = batch.shape[0], batch.shape[1] - 1
        dropout_mask = rand(*mask_shape) >= mlp[0].dropout_rate
        batch[:, :-1] *= dropout_mask
        
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
            if mlp[layer_idx+1].dropout_rate > 0:
                # apply dropout where is it needed in the hidden layer
                # (columns - 1) to ignore biases
                mask_shape = layer.d_activations.shape[0], layer.d_activations.shape[1]
                dropout_mask = rand(*mask_shape) >= mlp[layer_idx+1].dropout_rate
                
                layer.activations[:, :-1] *= dropout_mask
                layer.d_activations *= dropout_mask
        
        visible = layer.activations
    
    return visible[:, :-1], batch

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count        
        
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]
    
    for layer in mlp:
        layer.W[:-1, :] *= 1 - layer.dropout_rate
    
    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y, batch_with_dropout = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch_with_dropout)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.lr = 0.15
        elif epoch == 170:
            for layer in mlp:
                layer.momentum = 0.5
                layer.lr = 0.01
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 5000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 512

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.11s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.10s, accuracy: 19.59
# Epoch 3:	########################################	elapsed: 1.10s, accuracy: 33.98
# Epoch 4:	########################################	elapsed: 1.12s, accuracy: 62.53
# Epoch 5:	########################################	elapsed: 1.08s, accuracy: 68.93
# Epoch 6:	########################################	elapsed: 1.08s, accuracy: 76.50
# Epoch 7:	########################################	elapsed: 1.09s, accuracy: 88.38
# Epoch 8:	########################################	elapsed: 1.07s, accuracy: 90.63
# Epoch 9:	########################################	elapsed: 1.14s, accuracy: 91.19
# Epoch 10:	########################################	elapsed: 1.12s, accuracy: 93.34
# Epoch 11:	########################################	elapsed: 1.04s, accuracy: 92.81
# Epoch 12:	########################################	elapsed: 1.06s, accuracy: 92.93
# Epoch 13:	########################################	elapsed: 1.21s, accuracy: 93.40
# Epoch 14:	########################################	elapsed: 1.11s, accuracy: 94.22
# Epoch 15:	########################################	elapsed: 1.08s, accuracy: 92.90
# Epoch 16:	########################################	elapsed: 1.07s, accuracy: 94.49
# Epoch 17:	########################################	elapsed: 1.02s, accuracy: 93.41
# Epoch 18:	########################################	elapsed: 1.04s, accuracy: 94.19
# Epoch 19:	########################################	elapsed: 1.04s, accuracy: 94.16
# Epoch 20:	########################################	elapsed: 1.04s, accuracy: 94.95
# Epoch 21:	########################################	elapsed: 1.09s, accuracy: 94.74
# Epoch 22:	########################################	elapsed: 1.08s, accuracy: 94.56
# Epoch 23:	########################################	elapsed: 1.07s, accuracy: 94.22
# Epoch 24:	########################################	elapsed: 1.03s, accuracy: 94.86
# Epoch 25:	########################################	elapsed: 1.02s, accuracy: 94.54
# Epoch 26:	########################################	elapsed: 1.04s, accuracy: 95.23
# Epoch 27:	########################################	elapsed: 1.04s, accuracy: 95.17
# Epoch 28:	########################################	elapsed: 1.08s, accuracy: 95.00
# Epoch 29:	########################################	elapsed: 1.06s, accuracy: 95.45
# Epoch 30:	########################################	elapsed: 1.01s, accuracy: 95.58
# Epoch 31:	########################################	elapsed: 1.05s, accuracy: 95.65
# Epoch 32:	########################################	elapsed: 1.08s, accuracy: 95.66
# Epoch 33:	########################################	elapsed: 1.03s, accuracy: 95.68
# Epoch 34:	########################################	elapsed: 1.03s, accuracy: 95.69
# Epoch 35:	########################################	elapsed: 0.98s, accuracy: 95.68
# Epoch 36:	########################################	elapsed: 1.00s, accuracy: 95.68
# Epoch 37:	########################################	elapsed: 1.09s, accuracy: 95.70
# Epoch 38:	########################################	elapsed: 1.01s, accuracy: 95.71
# Epoch 39:	########################################	elapsed: 1.01s, accuracy: 95.71
# Epoch 40:	########################################	elapsed: 1.03s, accuracy: 95.71
# Epoch 41:	########################################	elapsed: 1.02s, accuracy: 95.72
# Epoch 42:	########################################	elapsed: 1.05s, accuracy: 95.70
# Epoch 43:	########################################	elapsed: 1.03s, accuracy: 95.69
# Epoch 44:	########################################	elapsed: 1.00s, accuracy: 95.68
# Epoch 45:	########################################	elapsed: 1.03s, accuracy: 95.69
# Epoch 46:	########################################	elapsed: 1.01s, accuracy: 95.70
# Epoch 47:	########################################	elapsed: 1.02s, accuracy: 95.70
# Epoch 48:	########################################	elapsed: 1.06s, accuracy: 95.71
# Epoch 49:	########################################	elapsed: 1.12s, accuracy: 95.71
# Epoch 50:	########################################	elapsed: 1.02s, accuracy: 95.73
# Epoch 51:	########################################	elapsed: 0.97s, accuracy: 95.72
# Epoch 52:	########################################	elapsed: 1.05s, accuracy: 95.72
# Epoch 53:	########################################	elapsed: 1.03s, accuracy: 95.73
# Epoch 54:	########################################	elapsed: 1.05s, accuracy: 95.74
# Epoch 55:	########################################	elapsed: 1.04s, accuracy: 95.74
# Epoch 56:	########################################	elapsed: 1.02s, accuracy: 95.73
# Epoch 57:	########################################	elapsed: 1.03s, accuracy: 95.74
# Epoch 58:	########################################	elapsed: 1.01s, accuracy: 95.74
# Epoch 59:	########################################	elapsed: 1.02s, accuracy: 95.75
# Epoch 60:	########################################	elapsed: 1.02s, accuracy: 95.74
# Epoch 61:	########################################	elapsed: 1.03s, accuracy: 95.74
# Epoch 62:	########################################	elapsed: 1.05s, accuracy: 95.73
# Epoch 63:	########################################	elapsed: 0.98s, accuracy: 95.74
# Epoch 64:	########################################	elapsed: 1.07s, accuracy: 95.74
# Epoch 65:	########################################	elapsed: 1.11s, accuracy: 95.74
# Epoch 66:	########################################	elapsed: 1.07s, accuracy: 95.74
# Epoch 67:	########################################	elapsed: 1.05s, accuracy: 95.74
# Epoch 68:	########################################	elapsed: 0.81s, accuracy: 95.74
# Epoch 69:	########################################	elapsed: 0.84s, accuracy: 95.75
# Epoch 70:	########################################	elapsed: 0.86s, accuracy: 95.74
# Epoch 71:	########################################	elapsed: 0.84s, accuracy: 95.74
# Epoch 72:	########################################	elapsed: 0.91s, accuracy: 95.74
# Epoch 73:	########################################	elapsed: 0.82s, accuracy: 95.74
# Epoch 74:	########################################	elapsed: 0.78s, accuracy: 95.74
# Epoch 75:	########################################	elapsed: 0.80s, accuracy: 95.74
# Epoch 76:	########################################	elapsed: 0.81s, accuracy: 95.73
# Epoch 77:	########################################	elapsed: 0.78s, accuracy: 95.73
# Epoch 78:	########################################	elapsed: 0.78s, accuracy: 95.73
# Epoch 79:	########################################	elapsed: 0.81s, accuracy: 95.73
# Epoch 80:	########################################	elapsed: 0.77s, accuracy: 95.73
# Epoch 81:	########################################	elapsed: 0.78s, accuracy: 95.73
# Epoch 82:	########################################	elapsed: 0.82s, accuracy: 95.73
# Epoch 83:	########################################	elapsed: 0.82s, accuracy: 95.73
# Epoch 84:	########################################	elapsed: 0.81s, accuracy: 95.72
# Epoch 85:	########################################	elapsed: 0.78s, accuracy: 95.72
# Epoch 86:	########################################	elapsed: 0.80s, accuracy: 95.73
# Epoch 87:	########################################	elapsed: 0.79s, accuracy: 95.73
# Epoch 88:	########################################	elapsed: 0.80s, accuracy: 95.73
# Epoch 89:	########################################	elapsed: 0.88s, accuracy: 95.73
# Epoch 90:	########################################	elapsed: 0.83s, accuracy: 95.73
# Epoch 91:	########################################	elapsed: 0.83s, accuracy: 95.73
# Epoch 92:	########################################	elapsed: 0.96s, accuracy: 95.73
# Epoch 93:	########################################	elapsed: 1.17s, accuracy: 95.73
# Epoch 94:	########################################	elapsed: 1.05s, accuracy: 95.73
# Epoch 95:	########################################	elapsed: 1.13s, accuracy: 95.74
# Epoch 96:	########################################	elapsed: 1.03s, accuracy: 95.74
# Epoch 97:	########################################	elapsed: 0.96s, accuracy: 95.74
# Epoch 98:	########################################	elapsed: 1.05s, accuracy: 95.73
# Epoch 99:	########################################	elapsed: 1.13s, accuracy: 95.74
# Epoch 100:	########################################	elapsed: 1.13s, accuracy: 95.74
# Epoch 101:	########################################	elapsed: 0.97s, accuracy: 95.74
# Epoch 102:	########################################	elapsed: 0.95s, accuracy: 95.74
# Epoch 103:	########################################	elapsed: 1.08s, accuracy: 95.74
# Epoch 104:	########################################	elapsed: 1.12s, accuracy: 95.74
# Epoch 105:	########################################	elapsed: 0.91s, accuracy: 95.74
# Epoch 106:	########################################	elapsed: 0.93s, accuracy: 95.74
# Epoch 107:	########################################	elapsed: 0.91s, accuracy: 95.74
# Epoch 108:	########################################	elapsed: 1.04s, accuracy: 95.74
# Epoch 109:	########################################	elapsed: 1.06s, accuracy: 95.74
# Epoch 110:	########################################	elapsed: 1.06s, accuracy: 95.73
# Epoch 111:	########################################	elapsed: 1.07s, accuracy: 95.73
# Epoch 112:	########################################	elapsed: 0.92s, accuracy: 95.73
# Epoch 113:	########################################	elapsed: 0.95s, accuracy: 95.73
# Epoch 114:	########################################	elapsed: 0.95s, accuracy: 95.73
# Epoch 115:	########################################	elapsed: 0.94s, accuracy: 95.73
# Epoch 116:	########################################	elapsed: 0.91s, accuracy: 95.73
# Epoch 117:	########################################	elapsed: 0.89s, accuracy: 95.73
# Epoch 118:	########################################	elapsed: 0.94s, accuracy: 95.72
# Epoch 119:	########################################	elapsed: 0.83s, accuracy: 95.72
# Epoch 120:	########################################	elapsed: 0.83s, accuracy: 95.72
# Epoch 121:	########################################	elapsed: 0.88s, accuracy: 95.72
# Epoch 122:	########################################	elapsed: 1.00s, accuracy: 95.72
# Epoch 123:	########################################	elapsed: 1.02s, accuracy: 95.72
# Epoch 124:	########################################	elapsed: 0.86s, accuracy: 95.72
# Epoch 125:	########################################	elapsed: 0.92s, accuracy: 95.72
# Epoch 126:	########################################	elapsed: 0.91s, accuracy: 95.72
# Epoch 127:	########################################	elapsed: 0.89s, accuracy: 95.72
# Epoch 128:	########################################	elapsed: 0.88s, accuracy: 95.72
# Epoch 129:	########################################	elapsed: 0.90s, accuracy: 95.71
# Epoch 130:	########################################	elapsed: 0.96s, accuracy: 95.70
# Epoch 131:	########################################	elapsed: 1.18s, accuracy: 95.70
# Epoch 132:	########################################	elapsed: 0.93s, accuracy: 95.70
# Epoch 133:	########################################	elapsed: 0.96s, accuracy: 95.70
# Epoch 134:	########################################	elapsed: 0.90s, accuracy: 95.70
# Epoch 135:	########################################	elapsed: 0.89s, accuracy: 95.70
# Epoch 136:	########################################	elapsed: 0.94s, accuracy: 95.70
# Epoch 137:	########################################	elapsed: 0.84s, accuracy: 95.70
# Epoch 138:	########################################	elapsed: 0.91s, accuracy: 95.70
# Epoch 139:	########################################	elapsed: 0.92s, accuracy: 95.70
# Epoch 140:	########################################	elapsed: 0.87s, accuracy: 95.70
# Epoch 141:	########################################	elapsed: 0.91s, accuracy: 95.70
# Epoch 142:	########################################	elapsed: 0.88s, accuracy: 95.70
# Epoch 143:	########################################	elapsed: 0.96s, accuracy: 95.70
# Epoch 144:	########################################	elapsed: 1.02s, accuracy: 95.69
# Epoch 145:	########################################	elapsed: 1.33s, accuracy: 95.69
# Epoch 146:	########################################	elapsed: 0.98s, accuracy: 95.69
# Epoch 147:	########################################	elapsed: 0.84s, accuracy: 95.69
# Epoch 148:	########################################	elapsed: 0.87s, accuracy: 95.69
# Epoch 149:	########################################	elapsed: 0.85s, accuracy: 95.69
# Epoch 150:	########################################	elapsed: 0.92s, accuracy: 95.69
# Epoch 151:	########################################	elapsed: 0.91s, accuracy: 95.69
# Epoch 152:	########################################	elapsed: 0.89s, accuracy: 95.69
# Epoch 153:	########################################	elapsed: 0.91s, accuracy: 95.69
# Epoch 154:	########################################	elapsed: 0.87s, accuracy: 95.69
# Epoch 155:	########################################	elapsed: 0.99s, accuracy: 95.69
# Epoch 156:	########################################	elapsed: 0.96s, accuracy: 95.69
# Epoch 157:	########################################	elapsed: 0.91s, accuracy: 95.69
# Epoch 158:	########################################	elapsed: 0.95s, accuracy: 95.69
# Epoch 159:	########################################	elapsed: 1.12s, accuracy: 95.69
# Epoch 160:	########################################	elapsed: 1.03s, accuracy: 95.69
# Epoch 161:	########################################	elapsed: 0.95s, accuracy: 95.68
# Epoch 162:	########################################	elapsed: 0.91s, accuracy: 95.68
# Epoch 163:	########################################	elapsed: 1.14s, accuracy: 95.68
# Epoch 164:	########################################	elapsed: 0.90s, accuracy: 95.67
# Epoch 165:	########################################	elapsed: 0.88s, accuracy: 95.67
# Epoch 166:	########################################	elapsed: 0.87s, accuracy: 95.66
# Epoch 167:	########################################	elapsed: 0.99s, accuracy: 95.66
# Epoch 168:	########################################	elapsed: 0.94s, accuracy: 95.66
# Epoch 169:	########################################	elapsed: 0.91s, accuracy: 95.66
# Epoch 170:	########################################	elapsed: 0.90s, accuracy: 95.66
# Epoch 171:	########################################	elapsed: 0.89s, accuracy: 95.66
# Epoch 172:	########################################	elapsed: 0.89s, accuracy: 95.66
# Epoch 173:	########################################	elapsed: 0.93s, accuracy: 95.66
# Epoch 174:	########################################	elapsed: 1.02s, accuracy: 95.66
# Epoch 175:	########################################	elapsed: 0.91s, accuracy: 95.66
# Epoch 176:	########################################	elapsed: 1.08s, accuracy: 95.66
# Epoch 177:	########################################	elapsed: 1.00s, accuracy: 95.66
# Epoch 178:	########################################	elapsed: 1.11s, accuracy: 95.66
# Epoch 179:	########################################	elapsed: 1.07s, accuracy: 95.66
# Epoch 180:	########################################	elapsed: 0.97s, accuracy: 95.66
# Epoch 181:	########################################	elapsed: 0.97s, accuracy: 95.66
# Epoch 182:	########################################	elapsed: 0.94s, accuracy: 95.66
# Epoch 183:	########################################	elapsed: 0.87s, accuracy: 95.66
# Epoch 184:	########################################	elapsed: 1.01s, accuracy: 95.66
# Epoch 185:	########################################	elapsed: 0.94s, accuracy: 95.66
# Epoch 186:	########################################	elapsed: 1.04s, accuracy: 95.66
# Epoch 187:	########################################	elapsed: 0.90s, accuracy: 95.66
# Epoch 188:	########################################	elapsed: 0.88s, accuracy: 95.66
# Epoch 189:	########################################	elapsed: 0.84s, accuracy: 95.66
# Epoch 190:	########################################	elapsed: 0.86s, accuracy: 95.66
# Epoch 191:	########################################	elapsed: 0.87s, accuracy: 95.66
# Epoch 192:	########################################	elapsed: 0.86s, accuracy: 95.66
# Epoch 193:	########################################	elapsed: 0.89s, accuracy: 95.66
# Epoch 194:	########################################	elapsed: 0.85s, accuracy: 95.66
# Epoch 195:	########################################	elapsed: 0.86s, accuracy: 95.66
# Epoch 196:	########################################	elapsed: 0.82s, accuracy: 95.66
# Epoch 197:	########################################	elapsed: 0.88s, accuracy: 95.66
# Epoch 198:	########################################	elapsed: 0.84s, accuracy: 95.66
# Epoch 199:	########################################	elapsed: 0.84s, accuracy: 95.66
# Epoch 200:	########################################	elapsed: 0.85s, accuracy: 95.66
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 0.88
# 	layer 3: 4.00

# %% [markdown]
# ### MLP with dropout

# %%
mlp_with_dropout = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.2, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.5, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.5, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp_with_dropout, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.94s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.95s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.94s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.96s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.92s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.91s, accuracy: 11.35
# Epoch 7:	########################################	elapsed: 0.89s, accuracy: 11.35
# Epoch 8:	########################################	elapsed: 0.94s, accuracy: 11.35
# Epoch 9:	########################################	elapsed: 0.91s, accuracy: 11.35
# Epoch 10:	########################################	elapsed: 0.96s, accuracy: 11.35
# Epoch 11:	########################################	elapsed: 0.98s, accuracy: 22.75
# Epoch 12:	########################################	elapsed: 0.97s, accuracy: 20.35
# Epoch 13:	########################################	elapsed: 0.91s, accuracy: 21.07
# Epoch 14:	########################################	elapsed: 0.95s, accuracy: 24.78
# Epoch 15:	########################################	elapsed: 1.03s, accuracy: 33.65
# Epoch 16:	########################################	elapsed: 1.01s, accuracy: 45.33
# Epoch 17:	########################################	elapsed: 0.95s, accuracy: 57.87
# Epoch 18:	########################################	elapsed: 0.94s, accuracy: 64.52
# Epoch 19:	########################################	elapsed: 0.94s, accuracy: 69.74
# Epoch 20:	########################################	elapsed: 0.89s, accuracy: 72.41
# Epoch 21:	########################################	elapsed: 0.92s, accuracy: 71.19
# Epoch 22:	########################################	elapsed: 0.93s, accuracy: 72.70
# Epoch 23:	########################################	elapsed: 0.92s, accuracy: 76.00
# Epoch 24:	########################################	elapsed: 1.07s, accuracy: 76.49
# Epoch 25:	########################################	elapsed: 1.04s, accuracy: 78.43
# Epoch 26:	########################################	elapsed: 1.00s, accuracy: 79.35
# Epoch 27:	########################################	elapsed: 1.18s, accuracy: 78.88
# Epoch 28:	########################################	elapsed: 1.10s, accuracy: 80.03
# Epoch 29:	########################################	elapsed: 1.27s, accuracy: 80.65
# Epoch 30:	########################################	elapsed: 1.29s, accuracy: 80.78
# Epoch 31:	########################################	elapsed: 1.20s, accuracy: 82.30
# Epoch 32:	########################################	elapsed: 1.28s, accuracy: 82.08
# Epoch 33:	########################################	elapsed: 1.25s, accuracy: 84.09
# Epoch 34:	########################################	elapsed: 1.19s, accuracy: 83.73
# Epoch 35:	########################################	elapsed: 1.16s, accuracy: 84.56
# Epoch 36:	########################################	elapsed: 1.11s, accuracy: 82.79
# Epoch 37:	########################################	elapsed: 1.15s, accuracy: 85.48
# Epoch 38:	########################################	elapsed: 1.11s, accuracy: 84.82
# Epoch 39:	########################################	elapsed: 1.07s, accuracy: 86.50
# Epoch 40:	########################################	elapsed: 1.24s, accuracy: 86.62
# Epoch 41:	########################################	elapsed: 1.28s, accuracy: 86.50
# Epoch 42:	########################################	elapsed: 1.38s, accuracy: 87.63
# Epoch 43:	########################################	elapsed: 1.30s, accuracy: 86.33
# Epoch 44:	########################################	elapsed: 1.31s, accuracy: 88.30
# Epoch 45:	########################################	elapsed: 1.26s, accuracy: 86.78
# Epoch 46:	########################################	elapsed: 1.12s, accuracy: 88.97
# Epoch 47:	########################################	elapsed: 1.14s, accuracy: 88.67
# Epoch 48:	########################################	elapsed: 1.34s, accuracy: 89.41
# Epoch 49:	########################################	elapsed: 1.20s, accuracy: 89.06
# Epoch 50:	########################################	elapsed: 1.28s, accuracy: 88.06
# Epoch 51:	########################################	elapsed: 1.20s, accuracy: 89.33
# Epoch 52:	########################################	elapsed: 1.12s, accuracy: 88.83
# Epoch 53:	########################################	elapsed: 1.21s, accuracy: 89.24
# Epoch 54:	########################################	elapsed: 1.26s, accuracy: 89.64
# Epoch 55:	########################################	elapsed: 1.27s, accuracy: 89.61
# Epoch 56:	########################################	elapsed: 1.27s, accuracy: 90.23
# Epoch 57:	########################################	elapsed: 1.23s, accuracy: 89.65
# Epoch 58:	########################################	elapsed: 1.34s, accuracy: 89.74
# Epoch 59:	########################################	elapsed: 1.25s, accuracy: 90.67
# Epoch 60:	########################################	elapsed: 1.26s, accuracy: 90.14
# Epoch 61:	########################################	elapsed: 1.49s, accuracy: 90.23
# Epoch 62:	########################################	elapsed: 1.38s, accuracy: 90.75
# Epoch 63:	########################################	elapsed: 1.39s, accuracy: 90.76
# Epoch 64:	########################################	elapsed: 1.28s, accuracy: 91.15
# Epoch 65:	########################################	elapsed: 1.37s, accuracy: 91.20
# Epoch 66:	########################################	elapsed: 1.51s, accuracy: 91.63
# Epoch 67:	########################################	elapsed: 1.35s, accuracy: 90.79
# Epoch 68:	########################################	elapsed: 1.37s, accuracy: 91.11
# Epoch 69:	########################################	elapsed: 1.26s, accuracy: 91.90
# Epoch 70:	########################################	elapsed: 1.37s, accuracy: 91.47
# Epoch 71:	########################################	elapsed: 1.34s, accuracy: 90.27
# Epoch 72:	########################################	elapsed: 1.26s, accuracy: 91.91
# Epoch 73:	########################################	elapsed: 1.25s, accuracy: 91.54
# Epoch 74:	########################################	elapsed: 1.32s, accuracy: 92.15
# Epoch 75:	########################################	elapsed: 1.44s, accuracy: 92.10
# Epoch 76:	########################################	elapsed: 1.52s, accuracy: 91.50
# Epoch 77:	########################################	elapsed: 1.46s, accuracy: 91.34
# Epoch 78:	########################################	elapsed: 1.38s, accuracy: 91.96
# Epoch 79:	########################################	elapsed: 1.37s, accuracy: 91.46
# Epoch 80:	########################################	elapsed: 1.31s, accuracy: 91.97
# Epoch 81:	########################################	elapsed: 1.31s, accuracy: 92.15
# Epoch 82:	########################################	elapsed: 1.19s, accuracy: 92.42
# Epoch 83:	########################################	elapsed: 1.12s, accuracy: 92.76
# Epoch 84:	########################################	elapsed: 1.19s, accuracy: 92.33
# Epoch 85:	########################################	elapsed: 1.21s, accuracy: 91.94
# Epoch 86:	########################################	elapsed: 1.45s, accuracy: 91.87
# Epoch 87:	########################################	elapsed: 1.21s, accuracy: 91.75
# Epoch 88:	########################################	elapsed: 1.18s, accuracy: 92.62
# Epoch 89:	########################################	elapsed: 1.29s, accuracy: 92.40
# Epoch 90:	########################################	elapsed: 1.27s, accuracy: 91.81
# Epoch 91:	########################################	elapsed: 1.23s, accuracy: 92.75
# Epoch 92:	########################################	elapsed: 1.20s, accuracy: 92.39
# Epoch 93:	########################################	elapsed: 1.30s, accuracy: 92.58
# Epoch 94:	########################################	elapsed: 1.18s, accuracy: 92.22
# Epoch 95:	########################################	elapsed: 1.34s, accuracy: 92.42
# Epoch 96:	########################################	elapsed: 1.34s, accuracy: 91.93
# Epoch 97:	########################################	elapsed: 1.52s, accuracy: 92.14
# Epoch 98:	########################################	elapsed: 1.41s, accuracy: 92.24
# Epoch 99:	########################################	elapsed: 1.26s, accuracy: 92.34
# Epoch 100:	########################################	elapsed: 1.15s, accuracy: 93.15
# Epoch 101:	########################################	elapsed: 1.19s, accuracy: 92.14
# Epoch 102:	########################################	elapsed: 1.35s, accuracy: 92.78
# Epoch 103:	########################################	elapsed: 1.73s, accuracy: 92.19
# Epoch 104:	########################################	elapsed: 1.80s, accuracy: 92.49
# Epoch 105:	########################################	elapsed: 1.70s, accuracy: 92.99
# Epoch 106:	########################################	elapsed: 1.30s, accuracy: 93.07
# Epoch 107:	########################################	elapsed: 1.94s, accuracy: 91.83
# Epoch 108:	########################################	elapsed: 1.48s, accuracy: 92.37
# Epoch 109:	########################################	elapsed: 1.28s, accuracy: 92.85
# Epoch 110:	########################################	elapsed: 1.24s, accuracy: 92.57
# Epoch 111:	########################################	elapsed: 1.27s, accuracy: 92.71
# Epoch 112:	########################################	elapsed: 1.27s, accuracy: 92.65
# Epoch 113:	########################################	elapsed: 1.33s, accuracy: 93.09
# Epoch 114:	########################################	elapsed: 1.28s, accuracy: 92.23
# Epoch 115:	########################################	elapsed: 1.29s, accuracy: 92.49
# Epoch 116:	########################################	elapsed: 1.29s, accuracy: 92.70
# Epoch 117:	########################################	elapsed: 1.50s, accuracy: 92.81
# Epoch 118:	########################################	elapsed: 1.41s, accuracy: 92.57
# Epoch 119:	########################################	elapsed: 1.36s, accuracy: 93.02
# Epoch 120:	########################################	elapsed: 1.40s, accuracy: 92.99
# Epoch 121:	########################################	elapsed: 1.31s, accuracy: 92.88
# Epoch 122:	########################################	elapsed: 1.47s, accuracy: 92.62
# Epoch 123:	########################################	elapsed: 1.47s, accuracy: 92.43
# Epoch 124:	########################################	elapsed: 1.32s, accuracy: 92.75
# Epoch 125:	########################################	elapsed: 1.48s, accuracy: 92.70
# Epoch 126:	########################################	elapsed: 1.39s, accuracy: 92.59
# Epoch 127:	########################################	elapsed: 1.41s, accuracy: 92.83
# Epoch 128:	########################################	elapsed: 1.42s, accuracy: 92.67
# Epoch 129:	########################################	elapsed: 1.38s, accuracy: 92.67
# Epoch 130:	########################################	elapsed: 1.45s, accuracy: 92.44
# Epoch 131:	########################################	elapsed: 1.41s, accuracy: 92.97
# Epoch 132:	########################################	elapsed: 1.36s, accuracy: 92.88
# Epoch 133:	########################################	elapsed: 1.37s, accuracy: 92.61
# Epoch 134:	########################################	elapsed: 1.38s, accuracy: 92.66
# Epoch 135:	########################################	elapsed: 1.50s, accuracy: 93.23
# Epoch 136:	########################################	elapsed: 1.46s, accuracy: 93.47
# Epoch 137:	########################################	elapsed: 1.40s, accuracy: 92.45
# Epoch 138:	########################################	elapsed: 1.45s, accuracy: 93.07
# Epoch 139:	########################################	elapsed: 1.39s, accuracy: 93.29
# Epoch 140:	########################################	elapsed: 1.35s, accuracy: 92.59
# Epoch 141:	########################################	elapsed: 1.36s, accuracy: 93.21
# Epoch 142:	########################################	elapsed: 1.35s, accuracy: 92.89
# Epoch 143:	########################################	elapsed: 1.34s, accuracy: 92.89
# Epoch 144:	########################################	elapsed: 1.37s, accuracy: 93.42
# Epoch 145:	########################################	elapsed: 1.33s, accuracy: 92.64
# Epoch 146:	########################################	elapsed: 1.37s, accuracy: 92.95
# Epoch 147:	########################################	elapsed: 1.53s, accuracy: 93.11
# Epoch 148:	########################################	elapsed: 1.65s, accuracy: 92.80
# Epoch 149:	########################################	elapsed: 1.38s, accuracy: 92.82
# Epoch 150:	########################################	elapsed: 1.38s, accuracy: 92.99
# Epoch 151:	########################################	elapsed: 1.25s, accuracy: 92.92
# Epoch 152:	########################################	elapsed: 1.09s, accuracy: 93.04
# Epoch 153:	########################################	elapsed: 1.10s, accuracy: 92.89
# Epoch 154:	########################################	elapsed: 1.26s, accuracy: 93.36
# Epoch 155:	########################################	elapsed: 1.29s, accuracy: 93.18
# Epoch 156:	########################################	elapsed: 1.10s, accuracy: 93.41
# Epoch 157:	########################################	elapsed: 1.39s, accuracy: 93.45
# Epoch 158:	########################################	elapsed: 1.40s, accuracy: 93.23
# Epoch 159:	########################################	elapsed: 1.43s, accuracy: 92.85
# Epoch 160:	########################################	elapsed: 1.39s, accuracy: 93.10
# Epoch 161:	########################################	elapsed: 1.31s, accuracy: 93.12
# Epoch 162:	########################################	elapsed: 1.37s, accuracy: 93.32
# Epoch 163:	########################################	elapsed: 1.34s, accuracy: 93.38
# Epoch 164:	########################################	elapsed: 1.18s, accuracy: 93.64
# Epoch 165:	########################################	elapsed: 1.47s, accuracy: 93.65
# Epoch 166:	########################################	elapsed: 1.30s, accuracy: 93.61
# Epoch 167:	########################################	elapsed: 1.33s, accuracy: 93.39
# Epoch 168:	########################################	elapsed: 1.35s, accuracy: 93.27
# Epoch 169:	########################################	elapsed: 1.41s, accuracy: 93.07
# Epoch 170:	########################################	elapsed: 1.50s, accuracy: 93.40
# Epoch 171:	########################################	elapsed: 1.45s, accuracy: 93.42
# Epoch 172:	########################################	elapsed: 1.31s, accuracy: 93.44
# Epoch 173:	########################################	elapsed: 1.38s, accuracy: 93.39
# Epoch 174:	########################################	elapsed: 1.37s, accuracy: 93.46
# Epoch 175:	########################################	elapsed: 1.37s, accuracy: 93.70
# Epoch 176:	########################################	elapsed: 1.44s, accuracy: 93.44
# Epoch 177:	########################################	elapsed: 1.42s, accuracy: 93.61
# Epoch 178:	########################################	elapsed: 1.43s, accuracy: 93.60
# Epoch 179:	########################################	elapsed: 1.45s, accuracy: 93.49
# Epoch 180:	########################################	elapsed: 1.42s, accuracy: 93.63
# Epoch 181:	########################################	elapsed: 1.43s, accuracy: 93.71
# Epoch 182:	########################################	elapsed: 1.40s, accuracy: 93.58
# Epoch 183:	########################################	elapsed: 1.49s, accuracy: 93.39
# Epoch 184:	########################################	elapsed: 1.46s, accuracy: 93.40
# Epoch 185:	########################################	elapsed: 1.44s, accuracy: 93.40
# Epoch 186:	########################################	elapsed: 1.48s, accuracy: 93.44
# Epoch 187:	########################################	elapsed: 1.40s, accuracy: 93.68
# Epoch 188:	########################################	elapsed: 1.44s, accuracy: 93.66
# Epoch 189:	########################################	elapsed: 1.52s, accuracy: 93.69
# Epoch 190:	########################################	elapsed: 1.42s, accuracy: 93.70
# Epoch 191:	########################################	elapsed: 1.43s, accuracy: 93.60
# Epoch 192:	########################################	elapsed: 1.42s, accuracy: 93.82
# Epoch 193:	########################################	elapsed: 1.40s, accuracy: 93.73
# Epoch 194:	########################################	elapsed: 1.40s, accuracy: 93.84
# Epoch 195:	########################################	elapsed: 1.39s, accuracy: 93.95
# Epoch 196:	########################################	elapsed: 1.45s, accuracy: 93.86
# Epoch 197:	########################################	elapsed: 1.49s, accuracy: 93.67
# Epoch 198:	########################################	elapsed: 1.80s, accuracy: 93.76
# Epoch 199:	########################################	elapsed: 1.67s, accuracy: 93.79
# Epoch 200:	########################################	elapsed: 1.77s, accuracy: 93.66
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 1.00
# 	layer 3: 4.00
